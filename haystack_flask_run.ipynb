# %%
#install necessary package
# !pip install flask
# !pip install git+https://github.com/deepset-ai/haystack.git
# !pip install urllib3==1.25.4
# Out:
# ...
#   Cloning https://github.com/deepset-ai/haystack.git to /tmp/pip-req-build-2_dj5sp6
#   Running command git clone -q https://github.com/deepset-ai/haystack.git /tmp/pip-req-build-2_dj5sp6
# ...
#      |████████████████████████████████| 204kB 2.9MB/s
# ...
#      |████████████████████████████████| 51kB 5.8MB/s
# ...
#      |████████████████████████████████| 51kB 6.1MB/s
# ...
#      |████████████████████████████████| 81kB 7.6MB/s
# ...
#      |████████████████████████████████| 327kB 18.1MB/s
# ...
#      |████████████████████████████████| 327kB 34.9MB/s
# ...
#      |████████████████████████████████| 92kB 8.6MB/s
# ...
#      |████████████████████████████████| 983kB 36.7MB/s
# ...
#      |████████████████████████████████| 5.6MB 16.4MB/s
# ...
#      |████████████████████████████████| 102kB 9.6MB/s
# ...
#      |████████████████████████████████| 8.2MB 21.4MB/s
# ...
#      |████████████████████████████████| 348kB 35.2MB/s
# ...
#      |████████████████████████████████| 61kB 7.5MB/s
# ...
#      |████████████████████████████████| 51kB 5.7MB/s
# ...

# %%
#clone project
# !git clone https://@github.com/bishalgaire/Question-Answer.git
# !git clone https://nerisnow:nirisha98@github.com/nerisnow/HaystackQA-Scrapy
# %cd /content/Question-Answer/
# %cd /content/HaystackQA-Scrapy/Elastic-DPR
# Out:
# /content/HaystackQA-Scrapy/Elastic-DPR

# %%
#Install Elasticsearch
! wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.9.2-linux-x86_64.tar.gz -q
! tar -xzf elasticsearch-7.9.2-linux-x86_64.tar.gz
! chown -R daemon:daemon elasticsearch-7.9.2

import os
from subprocess import Popen, PIPE, STDOUT
es_server = Popen(['elasticsearch-7.9.2/bin/elasticsearch'],
                   stdout=PIPE, stderr=STDOUT,
                   preexec_fn=lambda: os.setuid(1)  # as daemon
                  )
# wait until ES has started
! sleep 30

# %%
 #install ngrok
 # !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
 # !unzip ngrok-stable-linux-amd64.zip
# Out:
# --2021-05-25 12:27:43--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 18.205.129.29, 34.226.165.133, 3.220.114.126, ...
# Connecting to bin.equinox.io (bin.equinox.io)|18.205.129.29|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13832437 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.19M  6.68MB/s    in 2.0s
#
# 2021-05-25 12:27:46 (6.68 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13832437/13832437]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
 #Expose colab for tunel
 get_ipython().system_raw('./ngrok http 5000 &')

# %%
 #get api
 # !curl -s http://localhost:4040/api/tunnels | python3 -c \
     'import sys, json; print("Execute the next cell and the go to the following URL: " +json.load(sys.stdin)["tunnels"][0]["public_url"])'
# Out:
# Execute the next cell and the go to the following URL: https://698bd5bd6d5b.ngrok.io

# %%
#Index Data in ES
# !python index.py
# Out:
# 2021-05-25 12:29:06.155663: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 05/25/2021 12:29:07 - INFO - faiss.loader -   Loading faiss with AVX2 support.
# 05/25/2021 12:29:07 - INFO - faiss.loader -   Loading faiss.
# 05/25/2021 12:29:08 - INFO - farm.modeling.prediction_head -   Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .
# 05/25/2021 12:29:09 - INFO - elasticsearch -   HEAD http://localhost:9200/ [status:200 request:0.104s]
# 05/25/2021 12:29:09 - INFO - elasticsearch -   PUT http://localhost:9200/amitblogs [status:200 request:0.422s]
# 05/25/2021 12:29:09 - INFO - elasticsearch -   PUT http://localhost:9200/label [status:200 request:0.266s]
# 05/25/2021 12:29:09 - INFO - haystack.preprocessor.utils -   Converting /content/HaystackQA-Scrapy/amitness/data/Behavioral Testing of NLP models with CheckList.txt
# ...

# %%
#flask app api
# !python app.py
# Out:
# 2021-05-25 12:30:29.356540: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 05/25/2021 12:30:30 - INFO - faiss.loader -   Loading faiss with AVX2 support.
# 05/25/2021 12:30:30 - INFO - faiss.loader -   Loading faiss.
# 05/25/2021 12:30:31 - INFO - farm.modeling.prediction_head -   Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .
# 05/25/2021 12:30:32 - INFO - root -   Loading restapi.
# 05/25/2021 12:30:32 - INFO - elasticsearch -   HEAD http://localhost:9200/ [status:200 request:0.005s]
# 05/25/2021 12:30:32 - INFO - elasticsearch -   HEAD http://localhost:9200/amitblogs [status:200 request:0.005s]
# 05/25/2021 12:30:32 - INFO - elasticsearch -   GET http://localhost:9200/amitblogs [status:200 request:0.002s]
# 05/25/2021 12:30:32 - INFO - elasticsearch -   PUT http://localhost:9200/amitblogs/_mapping [status:200 request:0.017s]
# ...

# %%
#!fuser -n tcp -k 5000
